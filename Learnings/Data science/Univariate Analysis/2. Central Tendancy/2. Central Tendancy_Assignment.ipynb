# %%
import pandas as pd
from Univariate import Univariate

# %%
dataset = pd.read_csv("Placement.csv")
_qual,_quan = Univariate.qualquan(dataset)

# %%
from Univariate import Univariate

# find frequency by using user defined method (freqTable)
Univariate.freqTable("degree_p", dataset)
# Out:
#     UniqueValues  Frequency  RelativeFrequency  CumulativeFrequency
# 0          65.00         20           0.093023             0.093023
# 1          66.00         13           0.060465             0.153488
# 2          72.00         12           0.055814             0.209302
# 3          64.00         11           0.051163             0.260465
# 4          58.00          9           0.041860             0.302326
# ..           ...        ...                ...                  ...
# 84         64.80          1           0.004651             0.981395
# 85         56.30          1           0.004651             0.986047
# 86         91.00          1           0.004651             0.990698
# 87         56.87          1           0.004651             0.995349
# 88         77.60          1           0.004651             1.000000
#
# [89 rows x 4 columns]

# %%
# find quan, qual by using user defined method (qualquan)
_qual,_quan = Univariate.qualquan(dataset)

# find Univariate by using user defined method (_Univariate)
Univariate._Univariate(_quan, dataset)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5 Rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# Min           1      40.89       37.0       50.0       50.0      51.21
# ...

# %%
descriptive = Univariate._Univariate(_quan, dataset)

# find OutliersColumns by using user defined method (OutliersColumns)
lesser, greater = Univariate.OutliersColumns(_quan, descriptive)
lesser, greater
# Out:
# (['hsc_p'], ['hsc_p', 'degree_p', 'salary'])

# %%
# Replacing Outliers by using user defined method (ReplacingOutliers)
_dataset = Univariate.ReplacingOutliers(lesser, greater, dataset, descriptive)

# %%
_descriptive = Univariate._Univariate(_quan, _dataset)
_descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5 Rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# Min           1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
lesser, greater = Univariate.OutliersColumns(_quan, _descriptive)
lesser, greater
# Out:
# ([], [])
