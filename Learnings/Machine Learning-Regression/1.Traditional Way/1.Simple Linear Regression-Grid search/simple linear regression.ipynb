# %%
#Pandas is a powerful and widely-used Python library for data manipulation and analysis.
#It provides data structures such as:
#DataFrame: 2-dimensional, tabular data structure (like a spreadsheet or SQL table).
#Series: 1-dimensional array-like object.
#as pd assigns the alias pd to the librar
import pandas as pd

# %%
# Read the csv file salary_data from the current directory and assign to variabe dataSet
dataSet = pd.read_csv("insurance.csv")

# %%
#Read the specifit coloumn (YearsExperience) from dataset variable and assign to variable independent
dataSet
//independent = dataSet[["YearsExperience"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 #Read the specifit coloumn (YearsExperience) from dataset variable and assign to variable independent
#       2 dataSet
# ----> 3 independent = dataSet[["YearsExperience"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
#Read the specifit coloumn (Salary) from dataset variable and assign to variable dependednt
dependednt = dataSet[["Salary"]]

# %%
#used to import the train_test_split function from the sklearn.model_selection module in the scikit-learn library
#Scikit-learn is a popular machine learning library in Python that provides tools for preprocessing, training, evaluating, and deploying machine learning models.
from sklearn.model_selection import train_test_split

# %%
#train_test_split is a utility function that is used to split a dataset into training and testing subsets
#X, y: The features (X) and target labels (y) of the dataset.
#test_size: Proportion of the dataset to be used for testing (e.g., test_size=0.2 means 20% for testing).
#train_size: Proportion of the dataset to be used for training (optional).
#random_state: Ensures reproducibility of results by fixing the random seed.
#shuffle: Whether to shuffle the data before splitting (default is True).

x_Train,x_Test,y_Train,y_Test = train_test_split(independent,dependednt,test_size=.30, random_state=0)

# %%
# imports the LinearRegression class from the sklearn.linear_model module in the scikit-learn library.
from sklearn.linear_model import LinearRegression

# %%
# Create a Linear Regression model
regressor = LinearRegression()

#fit is the method fit(X, y): Trains the model by finding the best-fit line.
regressor.fit(x_Train,y_Train)
# Out:
# LinearRegression()

# %%
#Slope (Coefficient)
weight = regressor.coef_

#Intercept
bais = regressor.intercept_

# %%
# Predict new values from x_test and assign the predicated value to y_pred
y_pred = regressor.predict(x_Test)

# The r2_score function  calculates the coefficient of determination (𝑅2). which measures how well a regression model predicts the target variable. 
# It provides a value between − ∞ and 1

from sklearn.metrics import r2_score
y_pred
# Out:
# array([[ 40817.78327049],
#        [123188.08258899],
#        [ 65154.46261459],
#        [ 63282.41035735],
#        [115699.87356004],
#        [108211.66453108],
#        [116635.89968866],
#        [ 64218.43648597],
#        [ 76386.77615802]])

# %%
# validate the model performance based on the test set (y_test) Value and  result set (preticated value) y_pred   
# If rscore = 1 then Perfect prediction
# If rscore = 0 then Model performs as well as predicting the mean of the target values
# If rscore < 0 then Model performs worse than predicting the mean
rscore = r2_score(y_Test, y_pred)
rscore
# Out:
# 0.9740993407213511

# %%
#(pickling) is the process of converting Python objects into a byte stream that can be saved to a file 
import pickle
filename = "simpleLinerRegressiion.sav"

# saving our model and its file name called simpleLinerRegressiion.svg
pickle.dump(regressor,open(filename,'wb'))

# %%
# Load and existing model and predict the new salary from the year of experiaice
load_model = pickle.load(open("simpleLinerRegressiion.sav", 'rb'))
result = load_model.predict([[22]])
result
# Out:
# C:\Users\chida\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[232703.13963746]])
