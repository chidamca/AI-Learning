# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance.csv")

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import r2_score

from sklearn.model_selection import GridSearchCV 
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':["squared_error", "friedman_mse", "absolute_error", "poisson"], 'max_features': ['sqrt', 'log2'], 'splitter':["best", "random"]}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
# fitting the model for grid search

# %%
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("TheR_scorevalueforbestparameter{}:".format(grid.best_params_))
# Out:
# TheR_scorevalueforbestparameter{'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008212      0.003318         0.004612        0.001072
# 1        0.009718      0.001166         0.007725        0.001600
# 2        0.009121      0.000972         0.004716        0.001034
# 3        0.009624      0.003383         0.005214        0.001355
# 4        0.007519      0.001551         0.003719        0.000748
# 5        0.007991      0.003262         0.003302        0.001079
# 6        0.007589      0.001127         0.003803        0.001573
# 7        0.006316      0.001945         0.004576        0.000988
# 8        0.024912      0.002565         0.003306        0.000872
# 9        0.019697      0.002191         0.003609        0.001201
# 10       0.026053      0.001619         0.004338        0.001128
# 11       0.024766      0.004022         0.003607        0.000585
# 12       0.011149      0.001415         0.005433        0.001789
# 13       0.009611      0.002092         0.004510        0.000839
# 14       0.009717      0.001918         0.003608        0.000964
# 15       0.008613      0.000921         0.003919        0.000588
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.758465
# 1   {'criterion': 'squared_error', 'max_features':...           0.744155
# 2   {'criterion': 'squared_error', 'max_features':...           0.705733
# 3   {'criterion': 'squared_error', 'max_features':...           0.574104
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.695040
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.589128
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.735109
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.675969
# 8   {'criterion': 'absolute_error', 'max_features'...           0.593164
# 9   {'criterion': 'absolute_error', 'max_features'...           0.629517
# 10  {'criterion': 'absolute_error', 'max_features'...           0.743956
# 11  {'criterion': 'absolute_error', 'max_features'...           0.669293
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.688399
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.742175
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.662027
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.657314
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.661953           0.648880           0.691161
# 1            0.566962           0.571281           0.699144
# 2            0.633476           0.708521           0.691446
# 3            0.546046           0.697726           0.632980
# 4            0.589419           0.673336           0.669853
# 5            0.543736           0.666527           0.664781
# 6            0.602666           0.731141           0.686117
# 7            0.583243           0.635108           0.628495
# 8            0.545542           0.674385           0.710319
# 9            0.509717           0.774187           0.720250
# 10           0.517502           0.734522           0.728463
# 11           0.534703           0.717215           0.685211
# 12           0.628347           0.789578           0.662982
# 13           0.574485           0.640184           0.704257
# 14           0.634376           0.693727           0.614946
# 15           0.570158           0.671914           0.727931
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.753040         0.702700        0.045462                1
# 1            0.687140         0.653736        0.071668               10
# 2            0.725722         0.692980        0.031684                3
# 3            0.609355         0.612042        0.052119               16
# 4            0.601611         0.645852        0.042173               13
# 5            0.685485         0.629932        0.054285               14
# 6            0.724117         0.695830        0.049727                2
# 7            0.713406         0.647244        0.044266               12
# 8            0.624290         0.629540        0.058211               15
# 9            0.707968         0.668328        0.091801                8
# 10           0.713032         0.687495        0.085589                5
# 11           0.657204         0.652725        0.062351               11
# 12           0.682099         0.690281        0.053873                4
# 13           0.714287         0.675078        0.060378                6
# 14           0.728623         0.666740        0.040768                9
# 15           0.737573         0.672978        0.060018                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# Age: 12
# BMI: 34
# Children: 3
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0
# C:\Users\chida\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction
# Out:
# array([4466.6214])
